# %%
import matplotlib.pyplot as plt

# %%
year=[2012,2013,2014,2015,2016,2017]
salary=[12,13,14,16,18,20]
population=[100,120,300,200,370,280]

# %%
plt.bar(year,salary,width=0.3)
plt.show()

# %%
year=["year-2012","year-2013","year-2014","year-2015","year-2016","year-2017"]
salary=[12,13,14,16,18,20]
plt.bar(year,salary,width=0.9) # here label on x axis is clubbed
plt.show()

# %%
year=["year-2012","year-2013","year-2014","year-2015","year-2016","year-2017"]
salary=[12,13,14,16,18,20]
plt.bar(year,salary,width=0.9)
plt.xticks(rotation=90)  # rotate the text by 90 deg
plt.show()
