# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=sns.load_dataset("flights") #check the data on github  https://github.com/mwaskom/seaborn-data
a
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.relplot(x="passengers",y="month",data=a) # we are specifing data present in a

# %%
sns.relplot(x="year",y="month",kind="line",data=a)

# %%
sns.relplot(x="passengers",y="month",hue="month",data=a) # we can visulize the data according to month or year

# %%
sns.relplot(x="passengers",y="month",hue="year",data=a)

# %%
b=sns.load_dataset("tips")
b
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="day",y="tip",data=b,kind="line") # kind help to change scatter to line graph

# %% [markdown]
# # categorical data ploting

# %%
sns.catplot(x="day",y="tip",data=b)

# %%
sns.catplot(x="day",y="tip",kind="violin",data=b) #violin make a graph in violin way

# %%
sns.catplot(x="day",y="tip",kind="boxen",data=b)

# %%
sns.boxplot(x="day",y="tip",data=b)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(y="total_bill" , data=b); # indivisual graph
plt.show()

# %%
sns.pairplot(b,hue = 'day') # A pairplot plot a pairwise relationships in a dataset.

# %% [markdown]
# # Univariate graph

# %%
from scipy import stats

# %%
c=np.random.normal(loc=5,size=100,scale=2)
sns.distplot(c)
# Out:
# /Users/prasantpoudel/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #  bivariate graph

# %% [markdown]
# # how to compare data

# %%
a=sns.load_dataset("iris")
b=sns.FacetGrid(a,col="species")
b.map(plt.hist,"sepal_length",edgecolor="black")

# %%
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style="darkgrid")  # change the back ground color
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)
